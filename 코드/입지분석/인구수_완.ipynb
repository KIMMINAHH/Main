# %%
import pandas as pd
import geopandas as gpd
import shapely

import pydeck as pdk

# %%
def polygon_to_coordinates(x): 
    lon, lat = x.exterior.xy 
    return [[x, y] for x, y in zip(lon, lat)]

# %%
charger = gpd.read_file('../../데이터/charger/시범 전기차충전소(시군구격자) 접근성.shp', encoding = 'utf-8')

charger
# Out:
#              gid sgg_nm_k   sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  \
# 0       다사55a53b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 1       다사53a53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 2       다사52b53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 3       다사53a57b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 4       다사53a54b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# ...          ...      ...        ...    ...       ...       ...     ...
# 419167  나바98a83b     None       None   None      None      None    None
# 419168  마바76a57a     None       None   None      None      None    None
# 419169  나바97a87b     None       None   None      None      None    None
# 419170  나바97a25b     None       None   None      None      None    None
# 419171  나바96a82b     None       None   None      None      None    None
#
#           value  stats_year  raw_d_year  \
# 0         1.609        2021      202112
# 1         0.402        2021      202112
# 2         0.535        2021      202112
# 3         1.357        2021      202112
# 4         0.701        2021      202112
# ...         ...         ...         ...
# 419167    7.706        2021      202112
# 419168    3.802        2021      202112
# 419169    4.755        2021      202112
# 419170    0.662        2021      202112
# 419171 -999.000        2021      202112
#
#                                                  geometry
# 0       POLYGON ((955000.000 1953500.000, 955000.000 1...
# 1       POLYGON ((953000.000 1953000.000, 953000.000 1...
# 2       POLYGON ((952500.000 1953000.000, 952500.000 1...
# 3       POLYGON ((953000.000 1957500.000, 953000.000 1...
# 4       POLYGON ((953000.000 1954500.000, 953000.000 1...
# ...                                                   ...
# 419167  POLYGON ((898000.000 1883500.000, 898000.000 1...
# 419168  POLYGON ((1176000.000 1857000.000, 1176000.000...
# 419169  POLYGON ((897000.000 1887500.000, 897000.000 1...
# 419170  POLYGON ((897000.000 1825500.000, 897000.000 1...
# 419171  POLYGON ((896000.000 1882500.000, 896000.000 1...
#
# [419172 rows x 11 columns]

# %%
charger = charger[charger['sido_nm_k'] == '서울특별시']

charger['gid']
# Out:
# 0       다사55a53b
# 1       다사53a53a
# 2       다사52b53a
# 3       다사53a57b
# 4       다사53a54b
#           ...
# 2415    다사70b52a
# 2416    다사67b48a
# 2417    다사68a47a
# 2418    다사68a51a
# 2419    다사68a49b
# Name: gid, Length: 2420, dtype: object

# %%
charger = charger.to_crs(epsg=4326)
charger['coordinates'] = charger['geometry'].apply(polygon_to_coordinates)

charger.index = range(1, len(charger) + 1)

center_list = list()
for i in charger['coordinates']:
    center = [[(i[0][0] + i[1][0] + i[2][0] + i[3][0])/4, (i[0][1] + i[1][1] + i[2][1] + i[3][1])/4]]
    center_list.append(center)

charger['coord_center'] = pd.DataFrame(center_list)
charger['regularize_value'] = charger['value'] / charger['value'].max()

layer = pdk.Layer(
    'PolygonLayer', # 사용할 Layer 타입
    charger, # 시각화에 쓰일 데이터프레임
    get_polygon='coordinates', # geometry 정보를 담고있는 컬럼 이름
    get_fill_color='[255*regularize_value, 100,255*regularize_value]', # 각 데이터 별 rgb 또는 rgba 값 (0~255)
    pickable=True, # 지도와 interactive 한 동작 on
    auto_highlight=True # 마우스 오버(hover) 시 박스 출력
    ,coverage = 0
)

center_seoul = [127.001699, 37.564214]

view_state = pdk.ViewState(
    longitude=center_seoul[0],
    latitude=center_seoul[1],
    zoom=10)

r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.show()
# Out:
# DeckGLWidget(carto_key=None, custom_libraries=[], google_maps_key=None, json_input='{"initialViewState": {"lat…

# %%
main_population = gpd.read_file('../../데이터/population/dobong_pop.shp', encoding = 'utf-8')
dongdaemoon_pop = gpd.read_file('../../데이터/population/dongdaemoon_pop.shp', encoding = 'utf-8')
dongjak_pop = gpd.read_file('../../데이터/population/dongjak_pop.shp', encoding = 'utf-8')
eunpyeong_pop = gpd.read_file('../../데이터/population/eunpyeong_pop.shp', encoding = 'utf-8')
gangbook_pop = gpd.read_file('../../데이터/population/gangbook_pop.shp', encoding = 'utf-8')
gangdong_pop =gpd.read_file('../../데이터/population/gangdong_pop.shp', encoding = 'utf-8')
gangnam_pop = gpd.read_file('../../데이터/population/gangnam_pop.shp', encoding = 'utf-8')
gangseo_pop = gpd.read_file('../../데이터/population/gangseo_pop.shp', encoding = 'utf-8')
geumcheon_pop = gpd.read_file('../../데이터/population/geumcheon_pop.shp', encoding = 'utf-8')
guro_pop = gpd.read_file('../../데이터/population/guro_pop.shp', encoding = 'utf-8')
gwanak_pop = gpd.read_file('../../데이터/population/gwanak_pop.shp', encoding = 'utf-8')
gwangjin_pop = gpd.read_file('../../데이터/population/gwangjin_pop.shp', encoding = 'utf-8')
jonglo_pop = gpd.read_file('../../데이터/population/jonglo_pop.shp', encoding = 'utf-8')
joonggoo_pop = gpd.read_file('../../데이터/population/joonggoo_pop.shp', encoding = 'utf-8')
joongrang_pop = gpd.read_file('../../데이터/population/joongrang_pop.shp', encoding = 'utf-8')
mapo_pop = gpd.read_file('../../데이터/population/mapo_pop.shp', encoding = 'utf-8')
nowon_pop = gpd.read_file('../../데이터/population/nowon_pop.shp', encoding = 'utf-8')
seocho_pop = gpd.read_file('../../데이터/population/seocho_pop.shp', encoding = 'utf-8')
seodaemun_pop = gpd.read_file('../../데이터/population/seodaemun_pop.shp', encoding = 'utf-8')
songpa_pop = gpd.read_file('../../데이터/population/songpa_pop.shp', encoding = 'utf-8')
sungbook_pop = gpd.read_file('../../데이터/population/sungbook_pop.shp', encoding = 'utf-8')
sungdong_pop = gpd.read_file('../../데이터/population/sungdong_pop.shp', encoding = 'utf-8')
yangcheon_pop = gpd.read_file('../../데이터/population/yangcheon_pop.shp', encoding = 'utf-8')
yeongdeungpo_pop = gpd.read_file('../../데이터/population/yeongdeungpo_pop.shp', encoding = 'utf-8')
yongsan_pop = gpd.read_file('../../데이터/population/yongsan_pop.shp', encoding = 'utf-8')

# %%
main_population = main_population.append(dongdaemoon_pop)
main_population = main_population.append(dongjak_pop)
main_population = main_population.append(eunpyeong_pop)
main_population = main_population.append(gangbook_pop)
main_population = main_population.append(gangdong_pop)
main_population = main_population.append(gangnam_pop)
main_population = main_population.append(gangseo_pop)
main_population = main_population.append(geumcheon_pop)
main_population = main_population.append(guro_pop)
main_population = main_population.append(gwanak_pop)
main_population = main_population.append(gwangjin_pop)
main_population = main_population.append(jonglo_pop)
main_population = main_population.append(joonggoo_pop)
main_population = main_population.append(joongrang_pop)
main_population = main_population.append(mapo_pop)
main_population = main_population.append(nowon_pop)
main_population = main_population.append(seocho_pop)
main_population = main_population.append(seodaemun_pop)
main_population = main_population.append(songpa_pop)
main_population = main_population.append(sungbook_pop)
main_population = main_population.append(sungdong_pop)
main_population = main_population.append(yangcheon_pop)
main_population = main_population.append(yeongdeungpo_pop)
main_population = main_population.append(yongsan_pop)

main_population
# Out:
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(dongdaemoon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(dongjak_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(eunpyeong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangbook_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangdong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangnam_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangseo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(geumcheon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(guro_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gwanak_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gwangjin_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(jonglo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(joonggoo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(joongrang_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(mapo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(nowon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(seocho_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(seodaemun_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(songpa_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(sungbook_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(sungdong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yangcheon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yeongdeungpo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_21596\307584019.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yongsan_pop)
#           gid      lbl     val  \
# 0    다사58b60a  4336.00  4336.0
# 1    다사60b61b   295.00   295.0
# 2    다사58b59b   120.00   120.0
# 3    다사59b65b   442.00   442.0
# 4    다사60a62a  9367.00  9367.0
# ..        ...      ...     ...
# 110  다사51a47b     None     NaN
# 111  다사54a46a     None     NaN
# 112  다사56a47a     None     NaN
# 113  다사56a50a     None     NaN
# 114  다사54b45a     None     NaN
#
#                                               geometry
# 0    POLYGON ((958500.000 1960000.000, 958500.000 1...
# 1    POLYGON ((960500.000 1961500.000, 960500.000 1...
# 2    POLYGON ((958500.000 1959500.000, 958500.000 1...
# 3    POLYGON ((959500.000 1965500.000, 959500.000 1...
# 4    POLYGON ((960000.000 1962000.000, 960000.000 1...
# ..                                                 ...
# 110  POLYGON ((951000.000 1947500.000, 951000.000 1...
# 111  POLYGON ((954000.000 1946000.000, 954000.000 1...
# 112  POLYGON ((956000.000 1947000.000, 956000.000 1...
# 113  POLYGON ((956000.000 1950000.000, 956000.000 1...
# 114  POLYGON ((954500.000 1945000.000, 954500.000 1...
#
# [3227 rows x 4 columns]

# %%
main_population = main_population.drop_duplicates(subset = 'gid')

j = list()
for i in main_population['gid']:
    if i not in list(charger['gid']):
        j.append(i)

test = main_population.copy()

test = test.set_index('gid')
test = test.loc[j,:]

# %%
test = test.to_crs(epsg=4326)
test['coordinates'] = test['geometry'].apply(polygon_to_coordinates)

test.index = range(1, len(test) + 1)

test_list = list()
for i in test['coordinates']:
    center = [[(i[0][0] + i[1][0] + i[2][0] + i[3][0])/4, (i[0][1] + i[1][1] + i[2][1] + i[3][1])/4]]
    test_list.append(center)

test['coord_center'] = pd.DataFrame(test_list)
test['regularize_val'] = test['val'] / test['val'].max()

layer = pdk.Layer(
    'PolygonLayer', # 사용할 Layer 타입
    test, # 시각화에 쓰일 데이터프레임
    get_polygon='coordinates', # geometry 정보를 담고있는 컬럼 이름
    get_fill_color='[255*regularize_val, 100,255*regularize_val]', # 각 데이터 별 rgb 또는 rgba 값 (0~255)
    pickable=True, # 지도와 interactive 한 동작 on
    auto_highlight=True # 마우스 오버(hover) 시 박스 출력
    ,coverage = 0
)

center_seoul = [127.001699, 37.564214]

view_state = pdk.ViewState(
    longitude=center_seoul[0],
    latitude=center_seoul[1],
    zoom=10)

r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.show()
# Out:
# DeckGLWidget(carto_key=None, custom_libraries=[], google_maps_key=None, json_input='{"initialViewState": {"lat…

# %%
# main_population = main_population.set_index('gid')

# main_population = main_population.drop(test.index)
main_population = main_population.reset_index()
main_population.to_excel('../../데이터/입지분석/인구수_완.xlsx')
