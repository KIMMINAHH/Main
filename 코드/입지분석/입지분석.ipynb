# %% [markdown]
# # 입지분석

# %% [markdown]
# # 서울시 격자별 인구수 데이터 전처리
# - [국토 정보 플랫폼](http://map.ngii.go.kr/ms/map/NlipMap.do) - 국토 통계지도에서 추출
#
# ![입지분석](../../이미지/입지분석/인구수_추출.png)
#
# - 시군구 전체의 경우에는 500m 격자단위로 추출할 수가 없어 각 구별로 500m 격자단위로 추출한 뒤 병합하여 중복치 제거

# %% [markdown]
# ## 사전 설치 라이브러리
# geopandas의 경우에는 GDAL, Fiona, pyproj, Shapely의 whl파일이 필요함.
#
# [링크](https://www.lfd.uci.edu/~gohlke/pythonlibs/#shapely)를 통해서 각자 파이썬, 운영체제 사양에 맞는 파일을 다운받은 뒤 아래 코드 실행

# %%
# geopandas를 설치하기 위한 사전 필요 파일들
# !pip install pyproj
# !pip install shapely
# !pip install GDAL
# !pip install Fiona

# !pip install geopandas

# !pip install pandas

# 지도 시각화
# !pip install pydeck

# %% [markdown]
# 필요 라이브러리 호출

# %%
import pandas as pd
import geopandas as gpd
import shapely

import pydeck as pdk
from shapely.geometry import Polygon, Point

# %%
main_population = gpd.read_file('../../데이터/population/dobong_pop.shp', encoding = 'utf-8')
dongdaemoon_pop = gpd.read_file('../../데이터/population/dongdaemoon_pop.shp', encoding = 'utf-8')
dongjak_pop = gpd.read_file('../../데이터/population/dongjak_pop.shp', encoding = 'utf-8')
eunpyeong_pop = gpd.read_file('../../데이터/population/eunpyeong_pop.shp', encoding = 'utf-8')
gangbook_pop = gpd.read_file('../../데이터/population/gangbook_pop.shp', encoding = 'utf-8')
gangdong_pop =gpd.read_file('../../데이터/population/gangdong_pop.shp', encoding = 'utf-8')
gangnam_pop = gpd.read_file('../../데이터/population/gangnam_pop.shp', encoding = 'utf-8')
gangseo_pop = gpd.read_file('../../데이터/population/gangseo_pop.shp', encoding = 'utf-8')
geumcheon_pop = gpd.read_file('../../데이터/population/geumcheon_pop.shp', encoding = 'utf-8')
guro_pop = gpd.read_file('../../데이터/population/guro_pop.shp', encoding = 'utf-8')
gwanak_pop = gpd.read_file('../../데이터/population/gwanak_pop.shp', encoding = 'utf-8')
gwangjin_pop = gpd.read_file('../../데이터/population/gwangjin_pop.shp', encoding = 'utf-8')
jonglo_pop = gpd.read_file('../../데이터/population/jonglo_pop.shp', encoding = 'utf-8')
joonggoo_pop = gpd.read_file('../../데이터/population/joonggoo_pop.shp', encoding = 'utf-8')
joongrang_pop = gpd.read_file('../../데이터/population/joongrang_pop.shp', encoding = 'utf-8')
mapo_pop = gpd.read_file('../../데이터/population/mapo_pop.shp', encoding = 'utf-8')
nowon_pop = gpd.read_file('../../데이터/population/nowon_pop.shp', encoding = 'utf-8')
seocho_pop = gpd.read_file('../../데이터/population/seocho_pop.shp', encoding = 'utf-8')
seodaemun_pop = gpd.read_file('../../데이터/population/seodaemun_pop.shp', encoding = 'utf-8')
songpa_pop = gpd.read_file('../../데이터/population/songpa_pop.shp', encoding = 'utf-8')
sungbook_pop = gpd.read_file('../../데이터/population/sungbook_pop.shp', encoding = 'utf-8')
sungdong_pop = gpd.read_file('../../데이터/population/sungdong_pop.shp', encoding = 'utf-8')
yangcheon_pop = gpd.read_file('../../데이터/population/yangcheon_pop.shp', encoding = 'utf-8')
yeongdeungpo_pop = gpd.read_file('../../데이터/population/yeongdeungpo_pop.shp', encoding = 'utf-8')
yongsan_pop = gpd.read_file('../../데이터/population/yongsan_pop.shp', encoding = 'utf-8')

# %%
main_population = main_population.append(dongdaemoon_pop)
main_population = main_population.append(dongjak_pop)
main_population = main_population.append(eunpyeong_pop)
main_population = main_population.append(gangbook_pop)
main_population = main_population.append(gangdong_pop)
main_population = main_population.append(gangnam_pop)
main_population = main_population.append(gangseo_pop)
main_population = main_population.append(geumcheon_pop)
main_population = main_population.append(guro_pop)
main_population = main_population.append(gwanak_pop)
main_population = main_population.append(gwangjin_pop)
main_population = main_population.append(jonglo_pop)
main_population = main_population.append(joonggoo_pop)
main_population = main_population.append(joongrang_pop)
main_population = main_population.append(mapo_pop)
main_population = main_population.append(nowon_pop)
main_population = main_population.append(seocho_pop)
main_population = main_population.append(seodaemun_pop)
main_population = main_population.append(songpa_pop)
main_population = main_population.append(sungbook_pop)
main_population = main_population.append(sungdong_pop)
main_population = main_population.append(yangcheon_pop)
main_population = main_population.append(yeongdeungpo_pop)
main_population = main_population.append(yongsan_pop)

main_population = main_population.drop_duplicates(subset = 'gid')

main_population
# Out:
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(dongdaemoon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(dongjak_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(eunpyeong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangbook_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangdong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangnam_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gangseo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(geumcheon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(guro_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gwanak_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(gwangjin_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(jonglo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(joonggoo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(joongrang_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(mapo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(nowon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(seocho_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(seodaemun_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(songpa_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(sungbook_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(sungdong_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yangcheon_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yeongdeungpo_pop)
# C:\Users\ms964\AppData\Local\Temp\ipykernel_14300\705615383.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_population = main_population.append(yongsan_pop)
#           gid      lbl     val  \
# 0    다사58b60a  4336.00  4336.0
# 1    다사60b61b   295.00   295.0
# 2    다사58b59b   120.00   120.0
# 3    다사59b65b   442.00   442.0
# 4    다사60a62a  9367.00  9367.0
# ..        ...      ...     ...
# 100  다사54b47b     None     NaN
# 102  다사53a46a     None     NaN
# 103  다사54a48b     None     NaN
# 109  다사54a47b     None     NaN
# 111  다사54a46a     None     NaN
#
#                                               geometry
# 0    POLYGON ((958500.000 1960000.000, 958500.000 1...
# 1    POLYGON ((960500.000 1961500.000, 960500.000 1...
# 2    POLYGON ((958500.000 1959500.000, 958500.000 1...
# 3    POLYGON ((959500.000 1965500.000, 959500.000 1...
# 4    POLYGON ((960000.000 1962000.000, 960000.000 1...
# ..                                                 ...
# 100  POLYGON ((954500.000 1947500.000, 954500.000 1...
# 102  POLYGON ((953000.000 1946000.000, 953000.000 1...
# 103  POLYGON ((954000.000 1948500.000, 954000.000 1...
# 109  POLYGON ((954000.000 1947500.000, 954000.000 1...
# 111  POLYGON ((954000.000 1946000.000, 954000.000 1...
#
# [2634 rows x 4 columns]

# %% [markdown]
# ### 전기차 충전소 접근성 데이터 불러오기
# - 전기차 충전소 데이터를 먼저 불러오는 이유는 인구수 데이터의 경우 서울 외곽 지역의 경계선을 모두 포함하는 데이터이지만 전기차 충전소 데이터는 경계선을 포함하지 않는 데이터이기 때문에, 데이터를 전기차 충전소 데이터에 맞춰주기 위함임.
#
# 국토 정보 플랫폼에서 제공하는 데이터는 shp파일 형식이므로 geopandas의 read_file로 불러와야 함.
#
# shp파일은 함께 다운로드 된 dbf, prj, shx파일과 같은 위치에 있어야 파일 읽기 가능

# %%
charger = gpd.read_file('../../데이터/charger/시범 전기차충전소(시군구격자) 접근성.shp', encoding = 'utf-8')

charger
# Out:
#              gid sgg_nm_k   sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  \
# 0       다사55a53b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 1       다사53a53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 2       다사52b53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 3       다사53a57b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 4       다사53a54b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# ...          ...      ...        ...    ...       ...       ...     ...
# 419167  나바98a83b     None       None   None      None      None    None
# 419168  마바76a57a     None       None   None      None      None    None
# 419169  나바97a87b     None       None   None      None      None    None
# 419170  나바97a25b     None       None   None      None      None    None
# 419171  나바96a82b     None       None   None      None      None    None
#
#           value  stats_year  raw_d_year  \
# 0         1.609        2021      202112
# 1         0.402        2021      202112
# 2         0.535        2021      202112
# 3         1.357        2021      202112
# 4         0.701        2021      202112
# ...         ...         ...         ...
# 419167    7.706        2021      202112
# 419168    3.802        2021      202112
# 419169    4.755        2021      202112
# 419170    0.662        2021      202112
# 419171 -999.000        2021      202112
#
#                                                  geometry
# 0       POLYGON ((955000.000 1953500.000, 955000.000 1...
# 1       POLYGON ((953000.000 1953000.000, 953000.000 1...
# 2       POLYGON ((952500.000 1953000.000, 952500.000 1...
# 3       POLYGON ((953000.000 1957500.000, 953000.000 1...
# 4       POLYGON ((953000.000 1954500.000, 953000.000 1...
# ...                                                   ...
# 419167  POLYGON ((898000.000 1883500.000, 898000.000 1...
# 419168  POLYGON ((1176000.000 1857000.000, 1176000.000...
# 419169  POLYGON ((897000.000 1887500.000, 897000.000 1...
# 419170  POLYGON ((897000.000 1825500.000, 897000.000 1...
# 419171  POLYGON ((896000.000 1882500.000, 896000.000 1...
#
# [419172 rows x 11 columns]

# %%
charger = charger[charger['sido_nm_k'] == '서울특별시']

charger['gid']
# Out:
# 0       다사55a53b
# 1       다사53a53a
# 2       다사52b53a
# 3       다사53a57b
# 4       다사53a54b
#           ...
# 2415    다사70b52a
# 2416    다사67b48a
# 2417    다사68a47a
# 2418    다사68a51a
# 2419    다사68a49b
# Name: gid, Length: 2420, dtype: object

# %%
j = list() # 인구수 데이터 중 전기차 충전소 데이터의 위치와 일치하지 않는 데이터의 'gid' 추출
for i in main_population['gid']:
    if i not in list(charger['gid']):
        j.append(i)

not_in_population = main_population.copy()

not_in_population = not_in_population.set_index('gid')
not_in_population = not_in_population.loc[j,:]

not_in_population = not_in_population.reset_index()

# %%
def polygon_to_coordinates(x): 
    lon, lat = x.exterior.xy 
    return [[x, y] for x, y in zip(lon, lat)]

# %%
not_in_population = not_in_population.to_crs(epsg=4326)
not_in_population['coordinates'] = not_in_population['geometry'].apply(polygon_to_coordinates)

not_in_population_list = list()
for i in not_in_population['coordinates']:
    center = [[(i[0][0] + i[1][0] + i[2][0] + i[3][0])/4, (i[0][1] + i[1][1] + i[2][1] + i[3][1])/4]]
    not_in_population_list.append(center)

not_in_population['coord_center'] = pd.DataFrame(not_in_population_list)
not_in_population['regularize_val'] = not_in_population['val'] / not_in_population['val'].max()
not_in_population['regularize_val'] = not_in_population['regularize_val'].fillna(0)
layer = pdk.Layer(
    'PolygonLayer', # 사용할 Layer 타입
    not_in_population, # 시각화에 쓰일 데이터프레임
    get_polygon='coordinates', # geometry 정보를 담고있는 컬럼 이름
    get_fill_color='[255, 100,255]', # 각 데이터 별 rgb 또는 rgba 값 (0~255)
    pickable=True, # 지도와 interactive 한 동작 on
    auto_highlight=True # 마우스 오버(hover) 시 박스 출력
    ,coverage = 0
)

center_seoul = [127.001699, 37.564214]

view_state = pdk.ViewState(
    longitude=center_seoul[0],
    latitude=center_seoul[1],
    zoom=10)

r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.show()
# Out:
# DeckGLWidget(carto_key=None, custom_libraries=[], google_maps_key=None, json_input='{"initialViewState": {"lat…

# %% [markdown]
# 경계지점 격자 제거

# %%
main_population = main_population.set_index('gid')
not_in_population = not_in_population.set_index('gid')

main_population = main_population.drop(not_in_population.index)
main_population = main_population.reset_index()

# %%
main_population = main_population.to_crs(epsg=4326)
main_population['coordinates'] = main_population['geometry'].apply(polygon_to_coordinates)

main_population
# Out:
#            gid      lbl     val  \
# 0     다사58b60a  4336.00  4336.0
# 1     다사60b61b   295.00   295.0
# 2     다사58b59b   120.00   120.0
# 3     다사59b65b   442.00   442.0
# 4     다사60a62a  9367.00  9367.0
# ...        ...      ...     ...
# 2415  다사54b47b     None     NaN
# 2416  다사53a46a     None     NaN
# 2417  다사54a48b     None     NaN
# 2418  다사54a47b     None     NaN
# 2419  다사54a46a     None     NaN
#
#                                                geometry  \
# 0     POLYGON ((127.02962 37.63854, 127.02959 37.643...
# 1     POLYGON ((127.05221 37.65214, 127.05218 37.656...
# 2     POLYGON ((127.02965 37.63403, 127.02962 37.638...
# 3     POLYGON ((127.04065 37.68815, 127.04062 37.692...
# 4     POLYGON ((127.04651 37.65663, 127.04649 37.661...
# ...                                                 ...
# 2415  POLYGON ((126.98506 37.52568, 126.98503 37.530...
# 2416  POLYGON ((126.96818 37.51209, 126.96815 37.516...
# 2417  POLYGON ((126.97934 37.53467, 126.97931 37.539...
# 2418  POLYGON ((126.97940 37.52566, 126.97937 37.530...
# 2419  POLYGON ((126.97950 37.51214, 126.97947 37.516...
#
#                                             coordinates
# 0     [[127.02962122758167, 37.638535251970794], [12...
# 1     [[127.05220827725105, 37.652143202902444], [12...
# 2     [[127.0296496365157, 37.63402867517412], [127....
# 3     [[127.04064994099917, 37.68815209082502], [127...
# 4     [[127.04651278276538, 37.6566281247312], [127....
# ...                                                 ...
# 2415  [[126.98506171609876, 37.525681093742804], [12...
# 2416  [[126.96818235085506, 37.51208598634863], [126...
# 2417  [[126.9793406172334, 37.53466953408817], [126....
# 2418  [[126.97940326638944, 37.52565628661525], [126...
# 2419  [[126.97949718781426, 37.512136389382235], [12...
#
# [2420 rows x 5 columns]

# %%
main_population.index = range(1, len(main_population) + 1)

# 격자의 중심점 구하기
center_list = list()
for i in main_population['coordinates']:
    center = [[(i[0][0] + i[1][0] + i[2][0] + i[3][0])/4, (i[0][1] + i[1][1] + i[2][1] + i[3][1])/4]]
    center_list.append(center)

main_population['coord_center'] = pd.DataFrame(center_list)

# 데이터 시각화를 위해 정규화
main_population['regularize_val'] = main_population['val'] / main_population['val'].max()

layer = pdk.Layer(
    'PolygonLayer', # 사용할 Layer 타입
    main_population, # 시각화에 쓰일 데이터프레임
    get_polygon='coordinates', # geometry 정보를 담고있는 컬럼 이름
    get_fill_color='[255*regularize_val, 100,255*regularize_val]', # 각 데이터 별 rgb 또는 rgba 값 (0~255)
    pickable=True, # 지도와 interactive 한 동작 on
    auto_highlight=True # 마우스 오버(hover) 시 박스 출력
    ,coverage = 0
)

center_seoul = [127.001699, 37.564214]

view_state = pdk.ViewState(
    longitude=center_seoul[0],
    latitude=center_seoul[1],
    zoom=10)

r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.show()
# Out:
# DeckGLWidget(carto_key=None, custom_libraries=[], google_maps_key=None, json_input='{"initialViewState": {"lat…

# %%
main_population.to_excel('../../데이터/입지분석/인구수_완.xlsx')

# %% [markdown]
# ## 전기차 충전소 접근성
# - 위에서 불러낸 charger 변수를 사용한다

# %%
charger.head()
# Out:
#         gid sgg_nm_k   sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  value  \
# 0  다사55a53b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  1.609
# 1  다사53a53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.402
# 2  다사52b53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.535
# 3  다사53a57b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  1.357
# 4  다사53a54b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.701
#
#    stats_year  raw_d_year                                           geometry
# 0        2021      202112  POLYGON ((955000.000 1953500.000, 955000.000 1...
# 1        2021      202112  POLYGON ((953000.000 1953000.000, 953000.000 1...
# 2        2021      202112  POLYGON ((952500.000 1953000.000, 952500.000 1...
# 3        2021      202112  POLYGON ((953000.000 1957500.000, 953000.000 1...
# 4        2021      202112  POLYGON ((953000.000 1954500.000, 953000.000 1...

# %%
charger = charger.to_crs(epsg=4326)
charger['coordinates'] = charger['geometry'].apply(polygon_to_coordinates)
charger.head()
# Out:
#         gid sgg_nm_k   sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  value  \
# 0  다사55a53b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  1.609
# 1  다사53a53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.402
# 2  다사52b53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.535
# 3  다사53a57b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  1.357
# 4  다사53a54b      종로구  Jongno-gu  11110     서울특별시     Seoul      11  0.701
#
#    stats_year  raw_d_year                                           geometry  \
# 0        2021      202112  POLYGON ((126.99035 37.57979, 126.99032 37.584...
# 1        2021      202112  POLYGON ((126.96773 37.57518, 126.96770 37.579...
# 2        2021      202112  POLYGON ((126.96207 37.57515, 126.96204 37.579...
# 3        2021      202112  POLYGON ((126.96744 37.61574, 126.96741 37.620...
# 4        2021      202112  POLYGON ((126.96764 37.58870, 126.96761 37.593...
#
#                                          coordinates
# 0  [[126.99035203836993, 37.57978500226289], [126...
# 1  [[126.96773397496594, 37.57517845860917], [126...
# 2  [[126.9620717979233, 37.575152792602694], [126...
# 3  [[126.9674449940854, 37.615737545688575], [126...
# 4  [[126.96763771237315, 37.58869818555969], [126...

# %%
main_population = main_population.set_index('gid')
charger = charger.set_index('gid')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ms964\Desktop\민서\vscode\Github\Main\코드\입지분석\입지분석.ipynb 셀 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ms964/Desktop/%EB%AF%BC%EC%84%9C/vscode/Github/Main/%EC%BD%94%EB%93%9C/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> main_population = main_population.set_index('gid')
#       <a href='vscode-notebook-cell:/c%3A/Users/ms964/Desktop/%EB%AF%BC%EC%84%9C/vscode/Github/Main/%EC%BD%94%EB%93%9C/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> charger = charger.set_index('gid')
#       <a href='vscode-notebook-cell:/c%3A/Users/ms964/Desktop/%EB%AF%BC%EC%84%9C/vscode/Github/Main/%EC%BD%94%EB%93%9C/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D/%EC%9E%85%EC%A7%80%EB%B6%84%EC%84%9D.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> Main = main_population[['val']].join(charger['value'])
#
# File c:\Users\ms964\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\ms964\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5500, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5497                 missing.append(col)
#    5499 if missing:
# -> 5500     raise KeyError(f"None of {missing} are in the columns")
#    5502 if inplace:
#    5503     frame = self
#
# KeyError: "None of ['gid'] are in the columns"

# %%
Main = main_population[['val']].join(charger['value'])
Main.head()
# Out:
#              val  value
# gid
# 다사58b60a  4336.0  0.209
# 다사60b61b   295.0  2.541
# 다사58b59b   120.0  0.236
# 다사59b65b   442.0  0.487
# 다사60a62a  9367.0  0.318

# %%
Main.columns = ['인구수', '충전소_접근성']
Main.head()
# Out:
#              인구수  충전소_접근성
# gid
# 다사58b60a  4336.0    0.209
# 다사60b61b   295.0    2.541
# 다사58b59b   120.0    0.236
# 다사59b65b   442.0    0.487
# 다사60a62a  9367.0    0.318

# %% [markdown]
# ## 고속도로 IC 접근성

# %%
IC = gpd.read_file('../../데이터/입지분석/고속도로IC/179.2 IC(시군구격자) 접근성.shp', encoding = 'utf-8')
IC = IC[IC['sido_nm_k'] == '서울특별시']
IC
# Out:
#            gid sgg_nm_k     sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  \
# 0     다사52b55a      종로구    Jongno-gu  11110     서울특별시     Seoul      11
# 1     다사53a52b      종로구    Jongno-gu  11110     서울특별시     Seoul      11
# 2     다사53a58a      종로구    Jongno-gu  11110     서울특별시     Seoul      11
# 3     다사53b55a      종로구    Jongno-gu  11110     서울특별시     Seoul      11
# 4     다사57b52b      종로구    Jongno-gu  11110     서울특별시     Seoul      11
# ...        ...      ...          ...    ...       ...       ...     ...
# 2415  다사67b50a      강동구  Gangdong-gu  11740     서울특별시     Seoul      11
# 2416  다사70b52b      강동구  Gangdong-gu  11740     서울특별시     Seoul      11
# 2417  다사68a51b      강동구  Gangdong-gu  11740     서울특별시     Seoul      11
# 2418  다사71a52a      강동구  Gangdong-gu  11740     서울특별시     Seoul      11
# 2419  다사67a47a      강동구  Gangdong-gu  11740     서울특별시     Seoul      11
#
#       value  stats_year  raw_d_year  \
# 0     2.326        2021      202111
# 1     4.295        2021      202111
# 2     5.564        2021      202111
# 3     3.545        2021      202111
# 4     5.093        2021      202111
# ...     ...         ...         ...
# 2415  1.318        2021      202111
# 2416  2.063        2021      202111
# 2417  2.592        2021      202111
# 2418  2.748        2021      202111
# 2419  4.022        2021      202111
#
#                                                geometry
# 0     POLYGON ((952500.000 1955000.000, 952500.000 1...
# 1     POLYGON ((953000.000 1952500.000, 953000.000 1...
# 2     POLYGON ((953000.000 1958000.000, 953000.000 1...
# 3     POLYGON ((953500.000 1955000.000, 953500.000 1...
# 4     POLYGON ((957500.000 1952500.000, 957500.000 1...
# ...                                                 ...
# 2415  POLYGON ((967500.000 1950000.000, 967500.000 1...
# 2416  POLYGON ((970500.000 1952500.000, 970500.000 1...
# 2417  POLYGON ((968000.000 1951500.000, 968000.000 1...
# 2418  POLYGON ((971000.000 1952000.000, 971000.000 1...
# 2419  POLYGON ((967000.000 1947000.000, 967000.000 1...
#
# [2420 rows x 11 columns]

# %%
IC = IC[['gid','value']]
IC = IC.set_index('gid')
IC.columns = ['IC_접근성']
IC
# Out:
#           IC_access
# gid
# 다사52b55a      2.326
# 다사53a52b      4.295
# 다사53a58a      5.564
# 다사53b55a      3.545
# 다사57b52b      5.093
# ...             ...
# 다사67b50a      1.318
# 다사70b52b      2.063
# 다사68a51b      2.592
# 다사71a52a      2.748
# 다사67a47a      4.022
#
# [2420 rows x 1 columns]

# %%
Main = Main.join(IC)
Main
# Out:
#              인구수  충전소_접근성  IC_access
# gid
# 다사58b60a  4336.0    0.209      7.585
# 다사60b61b   295.0    2.541     10.969
# 다사58b59b   120.0    0.236      7.133
# 다사59b65b   442.0    0.487      6.647
# 다사60a62a  9367.0    0.318      7.329
# ...          ...      ...        ...
# 다사54b47b     NaN    0.682      3.484
# 다사53a46a     NaN    2.965      4.624
# 다사54a48b     NaN    0.967      4.667
# 다사54a47b     NaN    1.177      3.979
# 다사54a46a     NaN    6.187      4.711
#
# [2420 rows x 3 columns]

# %% [markdown]
# ## 주차장 접근성

# %%
parking = gpd.read_file('../../데이터/입지분석/주차장/176.2 주자창(시군구격자) 접근성.shp', encoding = 'utf-8')
parking
# Out:
#              gid sgg_nm_k   sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  \
# 0       다사53a54b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 1       다사53a57b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 2       다사52b53a      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 3       다사55a53b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# 4       다사56a52b      종로구  Jongno-gu  11110     서울특별시     Seoul      11
# ...          ...      ...        ...    ...       ...       ...     ...
# 419167  다마21b87b     None       None   None      None      None    None
# 419168  마바76b61a     None       None   None      None      None    None
# 419169  마바75b63a     None       None   None      None      None    None
# 419170  다사03a44a     None       None   None      None      None    None
# 419171  라아61b41b     None       None   None      None      None    None
#
#           value  stats_year  raw_d_year  \
# 0         0.831        2021      202110
# 1         1.357        2021      202110
# 2         0.394        2021      202110
# 3         1.570        2021      202110
# 4         0.060        2021      202110
# ...         ...         ...         ...
# 419167    7.448        2021      202110
# 419168 -999.000        2021      202110
# 419169    0.344        2021      202110
# 419170    2.123        2021      202110
# 419171 -999.000        2021      202110
#
#                                                  geometry
# 0       POLYGON ((953000.000 1954500.000, 953000.000 1...
# 1       POLYGON ((953000.000 1957500.000, 953000.000 1...
# 2       POLYGON ((952500.000 1953000.000, 952500.000 1...
# 3       POLYGON ((955000.000 1953500.000, 955000.000 1...
# 4       POLYGON ((956000.000 1952500.000, 956000.000 1...
# ...                                                   ...
# 419167  POLYGON ((921500.000 1787500.000, 921500.000 1...
# 419168  POLYGON ((1176500.000 1861000.000, 1176500.000...
# 419169  POLYGON ((1175500.000 1863000.000, 1175500.000...
# 419170  POLYGON ((903000.000 1944000.000, 903000.000 1...
# 419171  POLYGON ((1061500.000 2041500.000, 1061500.000...
#
# [419172 rows x 11 columns]

# %%
parking = parking[parking['sido_nm_k'] == '서울특별시']
parking = parking.set_index('gid')
parking
# Out:
#          sgg_nm_k     sgg_nm_e sgg_cd sido_nm_k sido_nm_e sido_cd  value  \
# gid
# 다사53a54b      종로구    Jongno-gu  11110     서울특별시     Seoul      11  0.831
# 다사53a57b      종로구    Jongno-gu  11110     서울특별시     Seoul      11  1.357
# 다사52b53a      종로구    Jongno-gu  11110     서울특별시     Seoul      11  0.394
# 다사55a53b      종로구    Jongno-gu  11110     서울특별시     Seoul      11  1.570
# 다사56a52b      종로구    Jongno-gu  11110     서울특별시     Seoul      11  0.060
# ...           ...          ...    ...       ...       ...     ...    ...
# 다사65b49b      강동구  Gangdong-gu  11740     서울특별시     Seoul      11  9.157
# 다사69a47b      강동구  Gangdong-gu  11740     서울특별시     Seoul      11  0.893
# 다사69b49a      강동구  Gangdong-gu  11740     서울특별시     Seoul      11  1.002
# 다사69b51b      강동구  Gangdong-gu  11740     서울특별시     Seoul      11  1.080
# 다사69b50a      강동구  Gangdong-gu  11740     서울특별시     Seoul      11  0.137
#
#           stats_year  raw_d_year  \
# gid
# 다사53a54b        2021      202110
# 다사53a57b        2021      202110
# 다사52b53a        2021      202110
# 다사55a53b        2021      202110
# 다사56a52b        2021      202110
# ...              ...         ...
# 다사65b49b        2021      202110
# 다사69a47b        2021      202110
# 다사69b49a        2021      202110
# 다사69b51b        2021      202110
# 다사69b50a        2021      202110
#
#                                                    geometry
# gid
# 다사53a54b  POLYGON ((953000.000 1954500.000, 953000.000 1...
# 다사53a57b  POLYGON ((953000.000 1957500.000, 953000.000 1...
# 다사52b53a  POLYGON ((952500.000 1953000.000, 952500.000 1...
# 다사55a53b  POLYGON ((955000.000 1953500.000, 955000.000 1...
# 다사56a52b  POLYGON ((956000.000 1952500.000, 956000.000 1...
# ...                                                     ...
# 다사65b49b  POLYGON ((965500.000 1949500.000, 965500.000 1...
# 다사69a47b  POLYGON ((969000.000 1947500.000, 969000.000 1...
# 다사69b49a  POLYGON ((969500.000 1949000.000, 969500.000 1...
# 다사69b51b  POLYGON ((969500.000 1951500.000, 969500.000 1...
# 다사69b50a  POLYGON ((969500.000 1950000.000, 969500.000 1...
#
# [2420 rows x 10 columns]

# %%
Main = Main.join(parking['value'])
Main.columns = ['인구수', '충전소_접근성', 'IC_접근성', '주차장_접근성']
Main
# Out:
#              인구수  충전소_접근성  IC_접근성  주차장_접근성
# gid
# 다사58b60a  4336.0    0.209   7.585    0.125
# 다사60b61b   295.0    2.541  10.969    2.390
# 다사58b59b   120.0    0.236   7.133    0.195
# 다사59b65b   442.0    0.487   6.647    0.463
# 다사60a62a  9367.0    0.318   7.329    0.348
# ...          ...      ...     ...      ...
# 다사54b47b     NaN    0.682   3.484    0.900
# 다사53a46a     NaN    2.965   4.624    0.472
# 다사54a48b     NaN    0.967   4.667    0.763
# 다사54a47b     NaN    1.177   3.979    2.386
# 다사54a46a     NaN    6.187   4.711    5.842
#
# [2420 rows x 4 columns]
