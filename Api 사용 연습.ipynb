# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "http://apis.data.go.kr/B552584/EvCharger/getChargerInfo?"
serviceKey = "serviceKey=39VhRE3v55MAxjUs4OzRl3DzMeHQbqydrQ1XB8b7yOa%2BKAzNE7vnJ289s6%2FyzSKzUHkrJ6l%2FZahhfZxKKUBrww%3D%3D"

numOfRows = "&numOfRows=10"

result = requests.get(url+serviceKey+numOfRows+"&pageNo=1")

soup = BeautifulSoup(result.text, 'lxml-xml')
items = soup.find_all('item')

print(items)
# Out:
# [<item><statNm>종묘 공영주차장</statNm><statId>ME000001</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 종로구 종로 157</addr><location>null</location><lat>37.571076</lat><lng>126.99588</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20220316144310</statUpdDt><lastTsdt>20211028002722</lastTsdt><lastTedt>20211028004608</lastTedt><nowTsdt/><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11110</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note/><limitYn>N</limitYn><limitDetail/><delYn>N</delYn><delDetail/></item>, <item><statNm>세종로 공영주차장</statNm><statId>ME000002</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 종로구 세종대로 189</addr><location>null</location><lat>37.573611</lat><lng>126.976011</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210831224310</statUpdDt><lastTsdt>20210826023834</lastTsdt><lastTedt>20210826030435</lastTedt><nowTsdt/><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11110</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note/><limitYn>N</limitYn><limitDetail/><delYn>N</delYn><delDetail/></item>, <item><statNm>그랜드앰배서더 서울</statNm><statId>ME000003</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 중구 동호로 287</addr><location>null</location><lat>37.559352</lat><lng>127.002350</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210910103310</statUpdDt><lastTsdt>20210905214809</lastTsdt><lastTedt>20210905221814</lastTedt><nowTsdt/><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11140</zscode><kind>E0</kind><kindDetail>E003</kindDetail><parkingFree>N</parkingFree><note/><limitYn>N</limitYn><limitDetail/><delYn>N</delYn><delDetail/></item>, <item><statNm>한강진역 공영주차장</statNm><statId>ME000004</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 용산구 한남동 산10-84</addr><location>null</location><lat>37.540085</lat><lng>127.002804</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210910095310</statUpdDt><lastTsdt>20210903090537</lastTsdt><lastTedt>20210903093530</lastTedt><nowTsdt/><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11170</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note/><limitYn>N</limitYn><limitDetail/><delYn>N</delYn><delDetail/></item>, <item><statNm>마장동사무소 앞(공중전화부스)</statNm><statId>ME000006</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 성동구 마장동 808</addr><location>null</location><lat>37.5660935</lat><lng>127.0455256</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20220729130810</statUpdDt><lastTsdt>20220729060427</lastTsdt><lastTedt>20220729064144</lastTedt><nowTsdt>20220729121546</nowTsdt><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11200</zscode><kind>G0</kind><kindDetail>G003</kindDetail><parkingFree>N</parkingFree><note/><limitYn>N</limitYn><limitDetail/><delYn>N</delYn><delDetail/></item>, <item><statNm>청량리롯데백화점</statNm><statId>ME000007</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 동대문구 왕산로 214</addr><location>null</location><lat>37.580650</lat><lng>127.047938</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20211025113310</statUpdDt><lastTsdt>20211023185504</lastTsdt><lastTedt>20211023185509</lastTedt><nowTsdt/><powerType/><output>50</output><method>단독</method><zcode>11</zcode><zscode>11230</zscode><kind>E0</kind><kindDetail>E002</ki ...

# %%
def parse():
    try:
        statNm = item.find("statNm").get_text()
        chgerType = item.find("chgerType").get_text()
        addr = item.find("addr").get_text()
        location = item.find("location").get_text()
        lat = item.find("lat").get_text()
        lng = item.find("lng").get_text()
        useTime = item.find("useTime").get_text()
        bnm = item.find("bnm").get_text()
        busiNm = item.find("busiNm").get_text()
        busiCall = item.find("busiCall").get_text()
        powerType = item.find("powerType").get_text()
        output = item.find("output").get_text()
        method = item.find("method").get_text()
        zcode = item.find("zcode").get_text()
        zscode = item.find("zscode").get_text()
        kind = item.find("kind").get_text()
        kindDetail = item.find("kindDetail").get_text()
        parkingFree = item.find("parkingFree").get_text()
        note = item.find("note").get_text()
        limitYn = item.find("limitYn").get_text()
        limitDetail = item.find("limitDetail").get_text()
        delYn = item.find("delYn").get_text()
        delDetail = item.find("delDetail").get_text()
        busiId = item.find("busiId").get_text()
        statId = item.find("statId").get_text()
        chgerId = item.find("chgerId").get_text()
        stat = item.find("stat").get_text()
        statUpdDt = item.find("statUpdDt").get_text()
        lastTsdt = item.find("lastTsdt").get_text()
        lastTedt = item.find("lastTedt").get_text()
        nowTsdt = item.find("nowTsdt").get_text()
        return {
            "충전소명":statNm,
            "충전기타입":chgerType,
            "주소":addr,
            "위치":location,
            "위도":lat,
            "경도":lng,
            "이용가능시간":useTime,
            "기관명":bnm,
            "운영기관명":busiNm,
            "운영기관연락처":busiCall,
            "배터리종류":powerType,
            "충전용량":output,
            "충전방식":method,
            "지역코드":zcode,
            "도로명주소":zscode,
            "종류":kind,
            "종류 디테일":kindDetail,
            "주차료무료":parkingFree,
            "충전소안내":note,
            "이용자제한":limitYn,
            "이용자제한사유":limitDetail,
            "삭제 여부":delYn,
            "삭제 사유":delDetail,
            "기관 아이디":busiId,
            "충전소ID":statId,
            "충전기ID":chgerId,
            "충전기상태":stat,
            "상태갱신일시":statUpdDt,
            "마지막 충전시작일시":lastTsdt,
            "마지막 충전종료일시":lastTedt,
            "충전중 시작일시":nowTsdt,
        }
    except AttributeError as e:
        return {
            "충전소명":None,
            "충전기타입":None,
            "주소":None,
            "위치":None,
            "위도":None,
            "경도":None,
            "이용가능시간":None,
            "기관명":None,
            "운영기관명":None,
            "운영기관연락처":None,
            "배터리종류":None,
            "충전용량":None,
            "충전방식":None,
            "지역코드":None,
            "도로명주소":None,
            "종류":None,
            "종류 디테일":None,
            "주차료무료":None,
            "충전소안내":None,
            "이용자제한":None,
            "이용자제한사유":None,
            "삭제 여부":None,
            "삭제 사유":None,
            "기관 아이디":None,
            "충전소ID":None,
            "충전기ID":None,
            "충전기상태":None,
            "상태갱신일시":None,
            "마지막 충전시작일시":None,
            "마지막 충전종료일시":None,
            "충전중 시작일시":None,
        }

# %%
row = []

# %%
soup = BeautifulSoup(result.text, 'lxml-xml')
items = soup.find_all('item')

for item in items:
    row.append(parse())

# %%
df = pd.DataFrame(row)

# %%
df
# Out:
#                충전소명 충전기타입                     주소    위치           위도  \
# 0          종묘 공영주차장    03       서울특별시 종로구 종로 157  null    37.571076
# 1         세종로 공영주차장    06     서울특별시 종로구 세종대로 189  null    37.573611
# 2        그랜드앰배서더 서울    06       서울특별시 중구 동호로 287  null    37.559352
# 3        한강진역 공영주차장    03   서울특별시 용산구 한남동 산10-84  null    37.540085
# 4  마장동사무소 앞(공중전화부스)    06      서울특별시 성동구 마장동 808  null   37.5660935
# 5          청량리롯데백화점    03     서울특별시 동대문구 왕산로 214  null    37.580650
# 6           이마트 이문점    03     서울특별시 동대문구 이문로 136  null    37.598454
# 7          홈플러스 월곡점    03       서울특별시 성북구 화랑로 76  null  37.60208293
# 8      성북벤처빌딩 공영주차장    06  서울특별시 성북구 장위2동 65-154  null     37.60936
# 9          롯데마트 삼양점    03      서울특별시 강북구 삼양로 247  null    37.625405
#
#              경도       이용가능시간  기관명 운영기관명    운영기관연락처  ... 삭제 여부 삭제 사유 기관 아이디  \
# 0     126.99588    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 1    126.976011    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 2    127.002350    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 3    127.002804    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 4   127.0455256    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 5    127.047938    24시간 이용가능  환경부   환경부  1661-9408  ...     N           ME
# 6    127.061848  10:00~24:00  환경부   환경부  1661-9408  ...     N           ME
# 7  127.04002398  10:00~24:00  환경부   환경부  1661-9408  ...     N           ME
# 8    127.053263               환경부   환경부  1661-9408  ...     N           ME
# 9    127.017897  10:00~24:00  환경부   환경부  1661-9408  ...     N           ME
#
#       충전소ID 충전기ID 충전기상태          상태갱신일시      마지막 충전시작일시      마지막 충전종료일시  \
# 0  ME000001    01     9  20220316144310  20211028002722  20211028004608
# 1  ME000002    01     9  20210831224310  20210826023834  20210826030435
# 2  ME000003    01     9  20210910103310  20210905214809  20210905221814
# 3  ME000004    01     9  20210910095310  20210903090537  20210903093530
# 4  ME000006    01     9  20220729130810  20220729060427  20220729064144
# 5  ME000007    01     9  20211025113310  20211023185504  20211023185509
# 6  ME000008    01     9  20210803110810  20210714170736  20210714174044
# 7  ME000011    01     9  20211029103810  20211026170744  20211026174039
# 8  ME000012    01     3  20220729191332  20220729183151  20220729191234
# 9  ME000013    01     9  20211123185310  00000000000000  20211008142006
#
#          충전중 시작일시
# 0
# 1
# 2
# 3
# 4  20220729121546
# 5
# 6
# 7
# 8  20220729191325
# 9
#
# [10 rows x 31 columns]

# %%
df.to_csv("/Users/kwonsunhyun/Desktop/apipractice.csv", mode="w")

# %%
data = pd.read_csv('/Users/kwonsunhyun/Desktop/apipractice.csv', index_col=0)

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#                충전소명  충전기타입                     주소  위치         위도          경도  \
# 0          종묘 공영주차장      3       서울특별시 종로구 종로 157 NaN  37.571076  126.995880
# 1         세종로 공영주차장      6     서울특별시 종로구 세종대로 189 NaN  37.573611  126.976011
# 2        그랜드앰배서더 서울      6       서울특별시 중구 동호로 287 NaN  37.559352  127.002350
# 3        한강진역 공영주차장      3   서울특별시 용산구 한남동 산10-84 NaN  37.540085  127.002804
# 4  마장동사무소 앞(공중전화부스)      6      서울특별시 성동구 마장동 808 NaN  37.566094  127.045526
# 5          청량리롯데백화점      3     서울특별시 동대문구 왕산로 214 NaN  37.580650  127.047938
# 6           이마트 이문점      3     서울특별시 동대문구 이문로 136 NaN  37.598454  127.061848
# 7          홈플러스 월곡점      3       서울특별시 성북구 화랑로 76 NaN  37.602083  127.040024
# 8      성북벤처빌딩 공영주차장      6  서울특별시 성북구 장위2동 65-154 NaN  37.609360  127.053263
# 9          롯데마트 삼양점      3      서울특별시 강북구 삼양로 247 NaN  37.625405  127.017897
#
#         이용가능시간  기관명 운영기관명    운영기관연락처  ...  삭제 여부  삭제 사유 기관 아이디     충전소ID  \
# 0    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000001
# 1    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000002
# 2    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000003
# 3    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000004
# 4    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000006
# 5    24시간 이용가능  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000007
# 6  10:00~24:00  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000008
# 7  10:00~24:00  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000011
# 8          NaN  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000012
# 9  10:00~24:00  환경부   환경부  1661-9408  ...      N    NaN     ME  ME000013
#
#    충전기ID 충전기상태          상태갱신일시      마지막 충전시작일시      마지막 충전종료일시      충전중 시작일시
# 0      1     9  20220316144310  20211028002722  20211028004608           NaN
# 1      1     9  20210831224310  20210826023834  20210826030435           NaN
# 2      1     9  20210910103310  20210905214809  20210905221814           NaN
# 3      1     9  20210910095310  20210903090537  20210903093530           NaN
# 4      1     9  20220729130810  20220729060427  20220729064144  2.022073e+13
# 5      1     9  20211025113310  20211023185504  20211023185509           NaN
# 6      1     9  20210803110810  20210714170736  20210714174044           NaN
# 7      1     9  20211029103810  20211026170744  20211026174039           NaN
# 8      1     3  20220729191332  20220729183151  20220729191234  2.022073e+13
# 9      1     9  20211123185310               0  20211008142006           NaN
#
# [10 rows x 31 columns]
